# %%
a=[10,3,7,8,2]

largest=0
second=0
for i in a:
    if i>largest:
        second=largest
        largest=i
    elif i>second and second!=largest:
        second=i

print(largest)
print(second)
# Out:
# 10
# 8

# %%
a,b,c=54,10,60

# %%
if ((a>b and c>a) or (a>b and c<a)):
    print(a)
elif((a<b and b<c)or (a>b and c<b)):
    print(b)
else:
    print(c)
# Out:
# 54

# %%
n=11
c=n
for i in range(1,n):
    if i <= n//2:
        print(i,end=' ')
    if i >= n//2:
        print(c,end= ' ')
        c-=1
# Out:
# 1 2 3 4 5 11 10 9 8 7 6

# %%
n=10
s=n//2
c=s
for i in range(1,n+1):
    if s==0 and c<=n:
        c+=1
        print(c,end=' ')
    else:
        print(s,end=' ')
        s-=1
# Out:
# 5 4 3 2 1 6 7 8 9 10

# %%
n=10
for i in range(1,n+1):
    print(i,n,end=' ')
    i+=2
    n-=2
# Out:
# 1 10 2 8 3 6 4 4 5 2 6 0 7 -2 8 -4 9 -6 10 -8

# %%
n=10
j=1
e=n
for i in range(1,n):
        print(j,n,end=' ')
        n-=2
        j+=2
        if j>e:
            break
# Out:
# 1 10 3 8 5 6 7 4 9 2

# %%
18//5
# Out:
# 3

# %%
a,b,c = 2,1,3

print(((a>b and c>a) or (a<b and a>c) and (f'a:',a)) or
       ((a<b and b<c) or (a>b and c<b) and (f'b:',b)) or
       (f'c:',c))
# Out:
# True

# %%
a,b,c=3,1,2

# %%
if (a<c and b<c):
    print('C:',c)
elif (a<b and b>c):
    print('B:',b)
else:
    print('A:',a)
# Out:
# A: 3

# %%
a,b,c=2,3,1

# %%
if (a<b and a<c):
    print("A:",a)
elif(a>b and b<c):
    print("B:",b)
else:
    print('C:',c)
# Out:
# C: 1

# %%
a,b,c,d=1,3,2,4
if (a<b and b<c and b<d):
    print('B:',b)
elif(a>b and a<c and a<d):
    print('A:',a)
elif(a<c and b>c and d>c):
    print('C:',c)
else:
    print('D:',d)
# Out:
# C: 2

# %%
print(21704**0.5)
# Out:
# 147.32277488562318
