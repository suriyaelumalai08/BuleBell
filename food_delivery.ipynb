# %%
print('hi')
# Out:
# hi

# %%
class data_class:
    def __init__(self):
        self.data=[]
        self.delivery=[]
        self.items=[]
    def new_user(self,data):
        self.data.append(data)
    def show_all_data(self):
        for i in self.data:
            print(i)

# %%
class custmore(data_class):
    def __init__(self,obj):
        self.data=obj.data
        self.items=obj.items
        self.delivery=obj.delivery
    def show_all_food_items(self):
        for i in self.items:
            print(i)
    def place_oder(self,food):
        pass
        # data={'food':food,'custmore_number':}
        # self.delivery.append(food)

# %%
class Admin(data_class):
    def __init__(self,obj):
        self.data=obj.data
        self.items=obj.items     
    def update(self,new_data):
        for user in self.data:
            if user['id']==new_data['id']:
                user.update(new_data)
    def food_idems_add(self,food_data):
        self.items.append(food_data)

# %%
class login(data_class):
    def __init__(self,obj):
        self.data=obj.data
    def login_user(self,id,name):
        try:
            for i in self.data:
                if i['id'] == id and i['name'] == name:
                    return True  
        except:
            return False

# %%
my_data_class=data_class()
# data1={'id':1,'name':'suriya','age':22,'number':99453362}
# data2={'id':2,'name':'anif','age':21,'number':85443762}
# data3={'id':3,'name':'mothis','age':21,'number':67453362}
# my_data_class.new_user(data1)
# my_data_class.new_user(data2)
# my_data_class.new_user(data3)

# %%
# my_data_class.show_all_data()
admin=Admin(my_data_class)
# my_data_class.show_all_data()
# new_data={'id': 4, 'name': 'velu', 'age': 20, 'number': 864583930}
# admin.new_user(new_data)
# my_data_class.show_all_data()

# %%
food1={'food_name':'Dosa','restaurants_name':'Amma_restaurants'}
food2={'food_name':'idli','restaurants_name':'abc_restaurants'}
food3={'food_name':'parottaaa','restaurants_name':'ns_restaurants'}
admin.food_idems_add(food1)
admin.food_idems_add(food2)
admin.food_idems_add(food3)
# admin.food_show()

# %%
cus=custmore(my_data_class)

# %%
oder='Dosa'
# cus.place_oder(oder)
# print('success')

# %%
login=login(my_data_class)
verif=login.login_user(id=3,name="anif")
print(verif)
# Out:
# None

# %%
if verif is True:
    cus.show_all_food_items()
else:
    print('your not a user of my class:')
    print('Do you want to register.')
# Out:
# your not a user of my class:
# Do you want to register.

# %%
continu=True

# %%
(1+0+1)/3
# Out:
# 0.6666666666666666

# %%
(1+4)/2
# Out:
# 2.5

# %%
import math
print(-(math.log(0.5)))
# Out:
# 0.6931471805599453

# %%
 = 0.67

# %%
class A:
    def show(a):
        print('hi')

# %%
a=A()
a.show()
# Out:
# hi
