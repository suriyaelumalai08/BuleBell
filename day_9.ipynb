# %%
print('hi')
# Out:
# hi

# %%
s='suriya'
out=''
for i in s:
    if i.lower() in 'aeiou':
        out+=i
print(out)
# Out:
# uia

# %%
a="suriya"
if a.lower() in 'aeiou':
    out+=a
print(out)
print(sorted(out))
# Out:
# uia
# ['a', 'i', 'u']

# %%
#For count the vowel character
count=0
for i in out:
    count+=1
print(count)
# Out:
# 3

# %%
len(out)
# Out:
# 3

# %%
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       3 my_len=len(i)
#       4 print(my_len)
# ----> 5 print(max(my_len))
#
# TypeError: 'int' object is not iterable

# %%
# Out:
# 21

# %%
if per[:-2:-1]==per[0]:
    print(True)
# Out:
# True

# %%
a='success'

# %%
split1=list(a)
split1
# Out:
# ['s', 'u', 'c', 'c', 'e', 's', 's']

# %%
var=[]
count=0

# %%
for i in split1:
    if i not in var:
        var.append(i)
    if i in var:
        count=+1
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
statement=False
per="tea,apple,eat,oop,pot"

for i in range(len(per)):

    if per[i]==',':
        if per[i-1]==per[i+1]:
            if per[0]==per[-1]:
                statement=True

print(statement)
# Out:
# True

# %%
a='success'

count={}

for i in a:
    if i in count:
        
        count[i]=count[i]+1
    else:
        count[i]=1
for key in count:
    print(f"{key}={count[key]}")
# Out:
# s=3
# u=1
# c=2
# e=1
