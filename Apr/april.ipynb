# %%
a,b,c = 10,20,30

print(int(a<b)<c and int(b>a)<c and int(a>c)<b and int(c<a)<b and int(b>c)<a and int(c<b)<a)
# Out:
# True

# %%
def fun (n):
    if n==0 or n==1:
        return 1
    else:
        return n* fun(n-1)
fun(5)
# Out:
# 120

# %%
n=427
a=n%10
b=(n//10)%10
c=n//100
print(a,b,c)
# Out:
# 7 2 4

# %%
n=9265
l=[]

while n>0:
    r=(0*10) + (n%10)
    l.append(r)
    n//=10

l
# Out:
# [5, 6, 2, 9]

# %%
9689%10
# Out:
# 9

# %%
n = 427
result = ''
temp1=0
temp2 = 0
while n >0:
    f = n%10
    temp1 = f
    if temp1 > temp2:
        result =str(temp1)+result
    else:
        result = result + str(temp1)
    n//=10
    temp2,f=temp1,0
print(result[::-1])
# Out:
# 274

# %%
num=427
result=0
while num>0:
    cur_value = num%10
    print(cur_value)
    result= result*10+cur_value
    print(result)
    num//=10
# Out:
# 7
# 7
# 2
# 72
# 4
# 724

# %%
num =427
result = 0

for  i in range(10):
    temp = num
    while temp > 0:
        curr = temp % 10 
        if curr == i:
            result = (result * 10) + curr
        temp//=10

print(result)
# Out:
# 247

# %%
for i in range(len(l)):
    for j in range(i + 1, len(l)):
        if l[i] > l[j]:
            l[i],l[j]= l[j],l[i]

l
# Out:
# [2, 5, 6, 9]

# %%
final_result =int(''.join(map(str,l)))
final_result
# Out:
# 2569

# %%
result=[]

for  i in range(len(l)-1,-1,-1):
    result.append(l[i])
result
# Out:
# [9, 6, 5, 2]

# %%
final_result =int(''.join(map(str,result)))
final_result
# Out:
# 9652
