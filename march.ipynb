# %% [markdown]
# 10 - march

# %%
print('jh')
# Out:
# jh

# %%
a="apple is tasty apple is yellow apple is green"
split_var=a.split()
print(a.split())
# Out:
# ['apple', 'is', 'tasty', 'apple', 'is', 'yellow', 'apple', 'is', 'green']

# %%
b=a.replace("apple","mango")
b
# Out:
# 'mango is tasty mango is yellow mango is green'

# %%
find="apple"
replace1="mango"
new_str=[]
statement=False

# %%
split_var[1].replace(find,replace1)
split_var
# Out:
# ['apple', 'is', 'tasty', 'apple', 'is', 'yellow', 'apple', 'is', 'green']

# %%
count=0
index=0
for i in split_var:
    if i ==find:
        count+=1
        print(f'{i},count:{count}')
        if count%2!=0:
            print(count)
            print(f'find:{find},replace:{replace1}')
            print(split_var[index])
# Out:
# apple,count:1
# 1
# find:apple,replace:mango
# apple
# apple,count:2
# apple,count:3
# 3
# find:apple,replace:mango
# apple

# %%
for i in range(10):
    if i%2=0:
        print(i)
    else:
        print("odd:",i)
# Out:
#   Cell In[8], line 2
#     if i%2=0:
#        ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
inp="apple is tasty apple is yellow apple is green"
spl=inp.split()
out="mongo is tasty apple is yellow mango is green"
find="apple"
replace1="mango"

# %%
print(type(spl))
spl[0].removesuffix("is")
print(spl)
# Out:
# <class 'list'>
# ['apple', 'is', 'tasty', 'apple', 'is', 'yellow', 'apple', 'is', 'green']

# %%
print(spl)
# Out:
# ['apple', 'is', 'tasty', 'apple', 'is', 'yellow', 'apple', 'is', 'green']

# %%
spl.remove(spl[0])
spl.insert(0,'ds')
print(spl)
# Out:
# ['ds', 'is', 'tasty', 'apple', 'is', 'yellow', 'apple', 'is', 'green']

# %%
for i in range(1,len(spl)+1):
    if spl[i-1]==find and i%2!=0:
       spl.remove(spl[i-1])
       spl.insert(i-1,replace1)
print(spl)
# Out:
# ['mango', 'is', 'tasty', 'is', 'yellow', 'apple', 'mango', 'is', 'green']

# %% [markdown]
# 11 March

# %%
def task_1(n):
    rev=0
    l=len(n)
    l
    for i in range(l):
        v=n[i]
        while v>0:
            rev=rev*10+v%10
            v=v//10
    
    # rev="{:,}".format(rev)
    print(rev)

# %%
inp1=(123,15,91,23,42,7)
inp2=(19,45,67,34)

task_1(inp1)
# Out:
# 321511932247

# %%
#Hostal

result = []

for num in inp1:
    rev=0
    n=num
    
    while n>0:
        rev=rev*10+n%10
        n=n//10
    
    result.append(rev)

print(tuple(result))
# Out:
# (321, 51, 19, 32, 24, 7)

# %%
321,51,19,32,24,7    91,54,76,43

# %%
inp1=(123,15,91,23,42,7)
rev=0
lis=[]
com=','
l=len(inp1)
for i in range(l):
    v=inp1[i]
    # print(i)
    while v>0:
        rev=rev*10+v%10
        v=v//10
    lis.append(rev)


# rev="{:,}".format(rev)
print(tuple(lis))
# Out:
# (321, 32151, 3215119, 321511932, 32151193224, 321511932247)

# %%
# Out:
# (321, 51, 19, 32, 24, 7)

# %%
s1={1,2,3,4,5,6}
s2={4,6,8,10}

print(s1&s2)
print(s1|s2)
# Out:
# {4, 6}
# {1, 2, 3, 4, 5, 6, 8, 10}

# %%
s1={12,13,14}
s2={12,13,14}

print(s1&s2)
print(s1|s2)
# Out:
# {12, 13, 14}
# {12, 13, 14}

# %%
s1={1,2,3,4,5,6}
s2={4,6,8,10}
print(s1.symmetric_difference(s2))
# Out:
# {1, 2, 3, 5, 8, 10}

# %%
print(s1^s2)
# Out:
# {1, 2, 3, 5, 8, 10}

# %%
s1={12,13,14}
s2={12,13,14}

print(s1.symmetric_difference(s2))
# Out:
# set()

# %%
t = (23,49,122,135,98)

digits = set()

for num in t:
    for d in str(num):
        digits.add(int(d))


print(digits)
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %%
t = (23,49,122,135,98)
result = []
for num in t:
    num=str(num)
    for digit in num:
        d=int(digit)
        if d not in result:
            result.append(d)

print(result, sep=",")
# Out:
# [2, 3, 4, 9, 1, 5, 8]

# %%
t1=(23,'tuple',3.14,7.5,"rock",7)
integer=[]
float1=[]
str2=[]
for i in range(len(t1)):
    if type(t1[i])==int:
       integer.append(t1[i])
    if type(t1[i])==float:
        float1.append(t1[i])
    if type(t1[i])==str:
        str2.append(t1[i])
print(integer)
print(float1)
print(str2)
# Out:
# [23, 7]
# [3.14, 7.5]
# ['tuple', 'rock']

# %%
n = (123,15,23,42,7)
res = '' 
for i in n: 
    while i > 0:
        res = str(i % 2) + res
        i //= 2
print(res)
# Out:
# 1111010101011111111111011

# %%
t = (123,15,23,42,7)

result = []

for num in t:
    n = num
    binary = ""

    while n > 0:
        binary = str(n % 2) + binary
        # print(binary)
        n = n // 2
        # print(n)

    result.append(binary)

print(result)
# Out:
# 1
# 11
# 011
# 1011
# 11011
# 111011
# 1111011
# 1
# 11
# 111
# 1111
# 1
# 11
# 111
# 0111
# 10111
# 0
# 10
# 010
# 1010
# 01010
# 101010
# 1
# 11
# 111
# ['1111011', '1111', '10111', '101010', '111']

# %%
students = {
    "Arun":[90,95,96],
    "Shankar":[20,34,45],
    "Ravi":[20,45,44]
        }

total={}
for name in students:
    total[name]=sum(students[name])

    # print(students[name])
    print(total[name])
sorted_students=sorted(total)

for i in sorted_students:
    print(i,end=", ")
# Out:
# 281
# 99
# 109
# Arun, Ravi, Shankar,

# %%
s={}
s['id']=123
s["name"]="suriya"
s['salary']=50000
s['persent_data']=[1,1,0,1,1]
print(s)
# Out:
# {'id': 123, 'name': 'suriya', 'salary': 50000, 'persent_data': [1, 1, 0, 1, 1]}

# %%
s['detiels']=[{'nam':'anif','age':22}]
print(s)
# Out:
# {'id': 123, 'name': 'suriya', 'salary': 50000, 'persent_data': [1, 1, 0, 1, 1], 'detiels': [{'nam': 'anif', 'age': 22}]}

# %%
class s:
  
    def add(self,data,str1,age):
        b[data]=data
    def show(self):
        for i in b:
            print(i)

# %%
s=s()

# %%
s.add(10,'suriya',22)
s.add(20,'sanjay',2)
s.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 s.add(10,'suriya',22)
#       2 s.add(20,'sanjay',2)
#       3 s.show()
#
# Cell In[28], line 4, in s.add(self, data, str1, age)
#       3 def add(self,data,str1,age):
# ----> 4     b[data]=data
#
# NameError: name 'b' is not defined

# %%
variable=[{'id': 1, 'name': 'a', 'marks': [2, 2, 2], 'Total': 6, 'avg': 2.0}, {'id': 2, 'name': 'b', 'marks': [3, 3, 3], 'Total': 9, 'avg': 3.0}, {'id': 3, 'name': 'c', 'marks': [4, 4, 4], 'Total': 12, 'avg': 4.0}]

# %%
i=len(variable)
print(i)
new_data=[]
for i in range(i):
    if new_data ==[]:
        new_data.append(variable[i])
        print(new_data)
    else:
        if new_data['Total']<variable[i]:
# Out:
#   Cell In[25], line 10
#
#     ^
# SyntaxError: incomplete input

# %%
for i in variable:
    print(i)
# Out:
# {'id': 1, 'name': 'a', 'marks': [2, 2, 2], 'Total': 6, 'avg': 2.0}
# {'id': 2, 'name': 'b', 'marks': [3, 3, 3], 'Total': 9, 'avg': 3.0}
# {'id': 3, 'name': 'c', 'marks': [4, 4, 4], 'Total': 12, 'avg': 4.0}

# %%
data=[{'id': 1, 'name': 'a', 'marks': [50, 50, 70], 'Total': 170, 'avg': 56.666666666666664}, {'id': 2, 'name': 'b', 'marks': [60, 45, 80], 'Total': 185, 'avg': 61.666666666666664}, {'id': 3, 'name': 'c', 'marks': [35, 60, 55], 'Total': 150, 'avg': 50.0}, {'id': 4, 'name': 'd', 'marks': [90, 80, 90], 'Total': 260, 'avg': 86.66666666666667}, {'id': 5, 'name': 'e', 'marks': [20, 30, 35], 'Total': 85, 'avg': 28.333333333333332}]

# %%
print(data)
# Out:
# [{'id': 1, 'name': 'a', 'marks': [50, 50, 70], 'Total': 170, 'avg': 56.666666666666664}, {'id': 2, 'name': 'b', 'marks': [60, 45, 80], 'Total': 185, 'avg': 61.666666666666664}, {'id': 3, 'name': 'c', 'marks': [35, 60, 55], 'Total': 150, 'avg': 50.0}, {'id': 4, 'name': 'd', 'marks': [90, 80, 90], 'Total': 260, 'avg': 86.66666666666667}, {'id': 5, 'name': 'e', 'marks': [20, 30, 35], 'Total': 85, 'avg': 28.333333333333332}]

# %%
new_data=sorted(data,key=lambda x:x['Total'],reverse=True)

# %%
new_data
# Out:
# [{'id': 4,
#   'name': 'd',
#   'marks': [90, 80, 90],
#   'Total': 260,
#   'avg': 86.66666666666667},
#  {'id': 2,
#   'name': 'b',
#   'marks': [60, 45, 80],
#   'Total': 185,
#   'avg': 61.666666666666664},
#  {'id': 1,
#   'name': 'a',
#   'marks': [50, 50, 70],
#   'Total': 170,
#   'avg': 56.666666666666664},
#  {'id': 3, 'name': 'c', 'marks': [35, 60, 55], 'Total': 150, 'avg': 50.0},
#  {'id': 5,
#   'name': 'e',
#   'marks': [20, 30, 35],
#   'Total': 85,
#   'avg': 28.333333333333332}]

# %%
class A:
    def showA(self):
        print('class A')
class B:
    def showB(self):
        print('class B')
class C(A,B):
    def showC(self):
        print('class C')

# %%
c=C()
c.showA()
c.showC()
c.showB()
# Out:
# class A
# class C
# class B

# %%
class A:
    def __init__(self):
        self.data=[{'sgsf':'dhddg','dhdg':'dgst'}]
class B(A):
    def __init__(self):
        super().__init__()
        print(self.data)

obj=B()
# Out:
# [{'sgsf': 'dhddg', 'dhdg': 'dgst'}]

# %%
class User_creation:
    def __init__(self,name,password):
        self.name=name
        self.password=password
    def show(self):
        print(self.name,self.password)

# %%
c=User_creation('suriya','suriya2004')
c.show()
# Out:
# suriya suriya2004

# %%
f='ndgndgrs'
s=set()
d=[]
for i in f:
    if i not in s:
       s.add(i)
    else:
        d.append(i)
print(s)
print(d)
# Out:
# {'g', 'n', 'd', 's', 'r'}
# ['n', 'd', 'g']

# %%
l=[1,2,3,4,5,6]
a=len(l)//2
left=0
right=len(l)-1
for i in range(a):
    l[left],l[right]=l[right],l[left]
    left+=1
    right-=1
    print(l)
# Out:
# [6, 2, 3, 4, 5, 1]
# [6, 5, 3, 4, 2, 1]
# [6, 5, 4, 3, 2, 1]

# %%
l=[1,2,4,5]
result=0
for i in range(len(l)):
    if i+1 not in l:
        result+=i+1
    
print(f'{l}->{result}')
# Out:
# [1, 2, 4, 5]->3

# %%
l1=[6, 2, 7,8,9, 1]
l2=[6, 5, 3, 4, 2, 1]
print(set(l1).intersection(set(l2)))
# Out:
# {1, 2, 6}

# %%
a=152
b=a
resutl1=0
while a>0:
    r=a%10
    v=r**3
    resutl1=resutl1+v
    # print(resutl1)
    a//=10
if b ==resutl1:
    print('armstrong ')
else:
    print('not armstrong')
# Out:
# not armstrong

# %%
n='653'

print(n.isalpha())
print(n.isnumeric())
# Out:
# False
# True

# %%
s='Program for to find the longest word in sentence'.split()
lar=set()
for i in range(len(s)):
    l=len(s[i])
    lar.add(l)
lenth=max(lar)

# %%
for i in range(len(s)):
    l=len(s[i])
    if l==lenth:
        print(s[i])
# Out:
# sentence

# %% [markdown]
# Task of 14 march

# %%
class Beginner_level:
    #task1 Print Hello world.
    def task1(self):
        print("hello world")

    #task2 add two numbers.
    def task2(self,a,b):
        print(f'Addcation of two number is {a}+{b}={a+b}')

    def task3(self,data,n):
        data=sorted(data)
        n=-(n+1)
        print(data[:n:-1])

    def task4(self,num):
        if (num%2)!=0:
            print('odd')
        else:
            print('even')

    def task5(self,a,b):
        print(f'Before Swap\na={a},b={b}')
        a,b=b,a
        print(f'After Swap\na={a},b={b}')

    def task6(self,num):
        if num==1:
            return 1
        else:
            return num*self.task6(num-1)

    def task7(self,num):
        if num<=1:
            return 'not a prime'
        else:
            is_prime=True
            for i in range(2,num):
                if num%i==0:
                    is_prime=False
                    break
        if is_prime:
            print(f'{num} is prime')
        else:
            print(f'{num} is not a prime')

    def task8(self,num):
        a,b=0,1
        print(f'{a}\n{b}')
        for i in range(1,num):
            c=a+b
            print(c)
            a,b=b,c

    def task9(self,num):
        res=0
        if num==0:
            print('0 is invalid')
        else:
            while num>0:
                res=res*10+num%10
                num//=10
        print(res)

    def task10(self,num):
        n=num
        res=0
        while num>0:
            res=res*10+num%10
            num//=10
        if n==res:
            print('palindrome')
        else:
            print('not palindrome')


t=Beginner_level()

# %%
class String_Problems:

    def task1(self,s):
        print(s[::-1])

    def task2(self,s):
        if s==s[::-1]:
            print('palindrome.')
        else:
            print('not palindrome.')

    def task3(self,s):
        count_vowel=0
        consonants=0
        for i in s:
            if i.lower() in 'aeiou':
                count_vowel+=1
            elif i==" ":
                continue
            else:
                consonants+=1
        print(f'vowel  count is {count_vowel} and consonants count is {consonants}')

    def task4(self,s):
        result=''
        for i in s:
            if i==' ':
                continue
            else:
                result+=i
        print(result)

    def task5(self,s):
        dumi=set()
        result=[]
        for i in s:
            if i not in dumi:
                dumi.add(i)
            else:
                result.append(i)
        print(result)

    def task6(self,s1,s2):
        print("yes" if sorted(s1)==sorted(s2) else "no")

    def task7(self,s):
        dumi=set()
        result=[]
        for i in s:
            if i not in dumi:
                dumi.add(i)
            else:
                result.append(i)
        for i in dumi:
            if i not in result:
                print(i)
                break

string=String_Problems()

# %%
class  Array_Problems:

    def task1(self,data):
        data=sorted(data)
        print(data[:-2:-1])

    def task2(self,data):
        first=0
        second=0
        for i in data:
            if i>first:
                second=first
                first=i
            elif i>second and second!=first:
                second=i
        print(second)

    def task3(self,data):
        data=set(data)
        print(list(data))

    def task4(self,s1,s2):
        print(s1&s2)

    def task5(self,data):
        n=len(data)
        for i in range(n):
            swape=False
            for j in range(0,n-i-1):
                if data[j]>data[j+1]:
                    data[j],data[j+1]=data[j+1],data[j]
                    swape=True
            if not swape:
                break
        print(data)

    def task6(self,data):
        a=len(data)//2
        left=0
        right=len(data)-1
        for i in range(a):
            data[left],data[right]=data[right],data[left]
            left+=1
            right-=1
        print(data)

    def task7(self,data):
        print(sum(data))

array=Array_Problems()

# %%
class Intermediate:

    def task1(self,data):
        result=0
        for i in range(len(data)):
            if i+1 not in data:
                result+=i+1
            
        print(f'{data}->{result}')

    def task2(self):
        pass

    def task3(self,l1,l2):
        print(set(l1)&set(l2))

    def task4(self,a):
        b=a
        resutl1=0
        while a>0:
            r=a%10
            v=r**3
            resutl1=resutl1+v
            a//=10
        if b ==resutl1:
            print('armstrong ')
        else:
            print('not armstrong')
    def task5(self):
        pass

    

intermediate=Intermediate()

# %%
import collections
class Advanced:
    def task1(self,s):
        lar=set()
        for i in range(len(s)):
            l=len(s[i])
            lar.add(l)
        lenth=max(lar)
        for i in range(len(s)):
            l=len(s[i])
            if l==lenth:
                print(s[i])
        
        #stackoverflow
    def task2(self,data):
        d = collections.defaultdict(list)
        for word in data:
            key = "".join(sorted(word))
            d[key].append(word)
        for key, anagrams in d.items():
            if len(anagrams) > 1:
                print(key, anagrams)
    def task3(self,data):
        data=set(data)
        print(list(data))



advanced=Advanced()
l=["hi", "hello", "bye", "helol", "abc", "cab", "bac", "silenced", "licensed", "declines"]
advanced.task2(l)
# Out:
# ehllo ['hello', 'helol']
# abc ['abc', 'cab', 'bac']
# cdeeilns ['silenced', 'licensed', 'declines']

# %%
n=28

old=[]
for i in range (1,n):
    old.append(i)
new_list=[]
for i in old:
    if (n%i)==0:
        new_list.append(i)
total=sum(new_list)
if total==n:
    print('perfect number')
else:
    print('not a perfect number')
# Out:
# perfect number

# %%
l=[1,2,5,10,20,30,40]
target=7
result=[]
for i in range(len(l)):
    for j in range(len(l)):
        if (l[i]+l[j])==target:
            result.append([l[i],l[j]])

# print(result)
new_res=[]
for i in result:
    if i not in new_res:
        new_res.append(i)

n=set()
result=[]
for i in new_res:
    p=tuple(sorted(i))
    if p not in n:
        n.add(p)
        result.append(list(p))
print(result)
# Out:
# [[2, 5]]

# %%
# Out:
# [[10, 40], [20, 30]]

# %%
l=[1,[2,[3,4]],5]
res1=[]
def faltten(lis):
    for i in lis:
        if type(i)==list:
            faltten(i)
        else:
            res1.append(i)
    return res1


faltten(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
from abc import ABC,abstractmethod

class A(ABC):
    @abstractmethod
    def showA(self):
        pass


class B(A):
    def showB(self):
        print('class B')


c=B()
c.showB()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 14
#      10     def showB(self):
#      11         print('class B')
# ---> 14 c=B()
#      15 c.showB()
#
# TypeError: Can't instantiate abstract class B with abstract method showA

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass  # Abstract method, to be implemented by subclasses

    def move(self):
        return "Moving"  # Concrete method with implementation
    

c=Animal()
print(c.move())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 11
#       7     def move(self):
#       8         return "Moving"  # Concrete method with implementation
# ---> 11 c=Animal()
#      12 print(c.move())
#
# TypeError: Can't instantiate abstract class Animal with abstract method make_sound

# %% [markdown]
# March 16

# %%
def isstring1(a,b):
    return a+b
def isnumbers1(a,b):
    return a+b

# %%
result='result is empty'
try:
    a='suriya'
    b='elumalai'

    if type(a) ==str and type(b)==str:
        result=isstring1(a,b)
    elif type(a)==int and type(b)==int:
        result=isnumbers1(a,b)
    else:
        print('invalid input so give a correct input.')   
except TypeError:
    print('error')
finally:
    print(result)
# Out:
# suriyaelumalai

# %%
def revers(num):
    rev=0
    while num > 0:
        rev=rev*10+num%10
        num//=10
    return rev

# %%
result=None
try:
    num='ldkjdsl'
    result=revers(num)
except Exception as e:
    print(f'The error is {e}')
finally:
    if result is not None:
        print(result)
    else:
        pass
# Out:
# The error is '>' not supported between instances of 'str' and 'int'

# %%
n='456'
print(n.isnumeric())
# Out:
# True

# %%
def recusion(num):
    
   
    add=0

    if 0<=result<=9:
        if result==1:
            print('happy')
        else:
            print('not happy')
    else:
        while result>0:
            res1=0
            res1=res1*10+result%10
            res1=res1**2
            add+=res1
            result//=10
        print(add)
    recusion(add)
  
recusion(5)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[151], line 21
#      18         print(add)
#      19     recusion(add)
# ---> 21 recusion(5)
#
# Cell In[151], line 6, in recusion(num)
#       1 def recusion(num):
#       4     add=0
# ----> 6     if 0<=result<=9:
#       7         if result==1:
#       8             print('happy')
#
# UnboundLocalError: cannot access local variable 'result' where it is not associated with a value

# %%
result=25

add=0
while result>0:
    res1=0
    res1=res1*10+result%10
    res1=res1**2
    add+=res1
    result//=10

print(a)
# Out:
# 29

# %%
def recusion(num):
    result = 0
    if num<=3:
        result=num**2
        if 0 <= result <=9:
            if result==1:
                return 'happy'
            else:
                return "not happy"
    elif num>=4 :
        result=num**2
        add=0
        while result>0:
            res1=0
            res1=res1*10+result%10
            res1=res1**2
            add+=res1
            result//=10
        print(add)
        return recusion(add)
    else:
        pass
    
    
recusion(5)

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# Task of 16 March Given by ALVIN ANNA

# %%
#Task1

def square(num):
    add=0
    while num>0:
        rev=0
        rev=rev*10+num%10
        rev=rev**2
        add+=rev
        num//=10
    return add


def func(num):
    if 0 <= num <=9:
        if num==1:
            print('Happy')
        else:
            print('Not Happy')
    if num>9:
        result=square(num)
        print(result)
        func(result)

func(100)
# Out:
# 1
# Happy

# %%
#Bubble Sorting
for i in range(len(n)):
    swape=False
    for j in range(0,len(n)-i-1):
        if n[j]>n[j+1]:
            n[j],n[j+1]=n[j+1],n[j]
            swape=True
    if not swape:
        break
print(n)
# Out:
# [1, 3, 5, 7, 8, 9]

# %%
#Pronic
N=12
result=""
for n in range(10):
    if n*(n+1) == N:
        result='pronic'
        break
    else:
        result='not a pronic'
print(result)
# Out:
# pronic

# %%
#Disarium
n=135
res=0
le=len(str(n))
check=n
while n>0:
    last=n%10
    res+=last**le
    le-=1
    n//=10
if check==res:
    print('Disarium')
else:
    print('Not Disarium')
# Out:
# Disarium

# %%
#Duck Number

# Go and see the d.py file for run time input()
n=473
flags=False
while n>0:
    r=0
    r=r*10+n%10
    n//=10
    if r==0:
        flags=True
if flags:
    print('Duck Number')
else:
    print('Not Duck Number')
# Out:
# Not Duck Number

# %% [markdown]
# march 21 Task

# %%
s="abbak"

left = 0
right = len(s)-1

print(left,right)

flags = True

for i in range(len(s)):
    if s[left] != s[right]:
        flags = False
    left += 1
    right -= 1

print(flags)
# Out:
# 0 4
# False

# %%
s1='abcba'

flags=False

for i in range(len(s1)):

    checker=s1[i]

    replace=s1.replace(checker,'',1)

    print(f'checker: {checker}, replace: {replace}')

    if replace == replace[::-1]:

        flags = True 
        
print(flags)
# Out:
# checker: a, replace: bcba
# checker: b, replace: acba
# checker: c, replace: abba
# checker: b, replace: acba
# checker: a, replace: bcba
# True

# %%
s='abcba'
index=s.rfind('a')
if index != 0:
    s = s[:index] + s[index+1:]
s
# Out:
# 'abcb'
