# %%
print('hi')
# Out:
# hi

# %%
n=345
rev=0
for i in n:
    d=n%10 #5,4,3
    rev=rev*10+d
    n=n//10
print(rev)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 n=345
#       2 rev=0
# ----> 3 for i in n:
#       4     d=n%10 #5,4,3
#       5     rev=rev*10+d
#
# TypeError: 'int' object is not iterable

# %%
def task_4(n):
    rev=0
    while n>0:
        i=n%10
        rev=rev*10+i
        n=n//10
    return rev

def task_3(n):
    odd=0
    even=0
    while n>0:
        if (n%2)==0:
            even+=n
        else:
            odd+=n
    return f"odd count: {odd},even count: {even}"

print(task_3(n=3))

# print(task_4(345))

# %%
num = 1221
# 
# 
temp = num
divior = 1

while temp>=10:
    temp//=10
    divior*=10

found = False
# print(divior)
while divior>0:
    left = num//(divior*10)
    right = num % divior
    new_num =  left * divior +right
    check_num = new_num

    rev = 0
    while check_num>0:
        rev=rev*10+check_num%10
        check_num//=10
    if new_num == rev:
        found = True
        break
    divior//=10
print(found)
# Out:
# True

# %%
num = 907654

count = 0

check = 0
temp = num
while temp>0:
    r=temp%10
    if r>check:
        check,r = r,check
        count=1
    if r==check:
        count+=1
    temp//=10

print(check,count)
# Out:
# 9 1

# %%
def factriol(num):
    if num==0 or num==1:
        return 1
    else:
        return num* factriol(num-1)
print(factriol(5))
# Out:
# 120

# %%
num =  123
temp1=num
org_result = 0
while temp1>0:
    n=temp1%10
    temp = n
    result=0
    if n!=1:
        while temp>0:
    
            if (temp-1)==0:
                break 
            result = n*(temp-1)
            n=result 
            temp-=1
        org_result +=result
    else:
        org_result+=1
    temp1//=10
print(org_result)
if org_result==num:
    print('storng number')
else:
    print('not storng number')
# Out:
# 9
# not storng number

# %%
num = 145
temp = num
result=0
while temp>0:
    digit = temp%10
    f=1
    s=1
    while s<=digit:
        f*=s
        s+=1
    result+=f
    temp//=10
print(result)
# Out:
# 145

# %%
n=5
temp = n
result=0
while temp>0:
    
    if (temp-1)==0:
        break 
    if temp == 1:
        result=1
        break   
    result = n*(temp-1)
    n=result 
    temp-=1
print(result)
# Out:
# 120

# %%
n=2
result = True
if n<=1:
    print(n)
    result=False
else:
    print(n)
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            result=False
print(result)
# Out:
# 2
# True

# %%
num =   444
temp = num
result=0
while temp>0:
    r = temp%10
    flags = True
    if r<=1:
        flags=False
    else:
        for i in range(2,int(r**0.5)+1):
            if r%i==0:
                flags=False
    if flags:
        result+=r
               
    temp//=10
print(result)
# Out:
# 0
