# %%
def And_operator(a,b):
    print (a and b)
    print(a or b)
    return None
And_operator(True,7>8)
# Out:
# False
# True

# %%
a=10
b=10

print(a is b)
print(id(a),id(b))
# Out:
# True
# 140705437639752 140705437639752

# %%
if a is not b:
    print(f'a: {id(a)}')
else:
    print(f'b: {id(b)}')
# Out:
# b: 140705437639752

# %%
5 + 7 * 6 - 3 // 2
# Out:
# 46

# %%
3//2
# Out:
# 1

# %%
5&(3|5)&3
# Out:
# 1

# %%
print(~(2**3<=3**2=10) )
# Out:
#   Cell In[3], line 1
#     print(~(2**3<=3**2=10) )
#                       ^
# SyntaxError: invalid syntax

# %%
10 -5*2 or not 5
# Out:
# False

# %%
10 -5*2 or 5
# Out:
# 5

# %%
 'e' and 'n' in 'friends'
# Out:
# True

# %%
print( ~(0xABC) )
# Out:
# -2749

# %%
print(0x196)
# Out:
# 406

# %%
a,b,c=9,12,11
x=a>b and a>c
y=x or a

z=y and b>c
v=b or c

t=z and v
print(x)
print(y)
print(z)
print(v)
print(t)
print( z and v )
# Out:
# False
# 9
# True
# 12
# 12
# 12

# %%
print(a>b and a>c and a or b>c and b or c)
# Out:
# 12
